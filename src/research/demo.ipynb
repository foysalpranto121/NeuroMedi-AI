# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# %pwd
# Out:
# 'm:\\All in one D\\NeuroMedi AI\\NeuroMedi-AI\\src\\research'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'm:\\All in one D\\NeuroMedi AI\\NeuroMedi-AI\\src'
